# %%
file1 = open("new 6.txt","r+")

# %%
value = file1.read()

# %%
value = value.replace('\n',' ')

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
stopwords = set(STOPWORDS)

# %%
value = value.replace('\t',' ')

# %%
from nltk.corpus import stopwords  
from nltk.tokenize import word_tokenize

# %%
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\AMD\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\AMD\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
stop_words = set(stopwords.words('english'))  
  
word_tokens = word_tokenize((temp))  
  
filtered_sentence = [w for w in word_tokens if not w in stop_words]  
  
filtered_sentence = []  
  
for w in word_tokens:  
    if w not in stop_words:  
        filtered_sentence.append(w)  
  
print(word_tokens)  
print(filtered_sentence)
# Out:
# ['Understanding', 'business', 'objectives', 'and', 'formulating', 'the', 'problem', 'as', 'a', 'Data', 'Science', 'problem', 'Design', 'train', 'and', 'deliver', 'Data', 'Science', 'solutions', 'using', 'all', 'modalities', 'tabular', 'text', 'image', 'and', 'of', 'all', 'sizes', 'small', 'or', 'big', 'data', 'In-depth', 'understanding', 'of', 'deep', 'learning', 'building', 'blocks', 'like', 'MLP', 'RNN', 'LSTM', 'CNN', 'Transformers', 'Proficiency', 'with', 'at', 'least', 'one', 'Deep', 'Learning', 'Framework', 'such', 'as', 'PyTorch', 'Tensorflow', 'etc', 'Develop', 'and', 'maintain', 'robust', 'data', 'processing', 'pipelines', 'and', 'reproducible', 'modelling', 'pipelines', 'Explore', 'data', 'and', 'communicate', 'insights', 'clearly', 'to', 'non-technical', 'as', 'well', 'as', 'technical', 'audience', 'Analyze', 'experimental', 'results', 'iterate', 'and', 'refine', 'models', 'to', 'create', 'significant', 'business', 'impact', 'Working', 'knowledge', 'of', 'OpenCV', 'Bachelorâ€™s', 'Degree', 'in', 'a', 'Quantitative', 'discipline', 'preferably', 'Computer', 'Science', '>', '3', 'yearsâ€™', 'experience', 'in', 'data', 'science', 'Analytics', 'roles', 'Proven', 'experience', 'as', 'a', 'Data', 'Scientist', 'or', 'similar', 'role', 'Expert', 'ability', 'to', 'write', 'robust', 'code', 'in', 'Python', 'Familiarity', 'with', 'standard', 'machine', 'learning', 'libraries', 'like', 'scikit-learn', 'StatsModels', 'Deep', 'Learning', 'Frameworks', 'like', 'Tensorflow', 'PyTorch', 'etc', 'Completed', 'Projects', 'on', 'Computer', 'Vision', 'and', 'Natural', 'Language', 'Processing', 'Excellent', 'verbal', 'and', 'written', 'communication', 'skills', 'You', 'take', 'complete', 'ownership', 'of', 'your', 'work', 'and', 'are', 'self-driven', 'Good', 'to', 'Have', 'Familiarity', 'in', 'working', 'with', 'Azure', 'AWS', 'GCP', 'etc', 'Experience', 'with', 'NoSQL', 'databases', 'such', 'as', 'MongoDB', 'Cassandra', 'Experience', 'with', 'containerizing', 'applications', 'using', 'Docker', 'Undertake', 'preprocessing', 'of', 'structured', 'and', 'unstructured', 'data', 'Create', 'and', 'maintain', 'data', 'quality', 'processes', 'Create', 'ETL', 'processes', 'to', 'move', 'large', 'amount', 'of', 'data', 'Analyze', 'large', 'amounts', 'of', 'information', 'to', 'discover', 'trends', 'and', 'patterns', 'Present', 'information', 'using', 'data', 'visualization', 'techniques', 'Propose', 'solutions', 'and', 'strategies', 'to', 'business', 'challenges', 'What', 'weâ€™re', 'looking', 'for', ':', '5', 'to', '8', 'Years', 'of', 'experience', 'as', 'a', 'Data', 'Scientist', 'Data', 'querying', 'data', 'analysis', 'data', 'wrangling', 'as', 'well', 'as', 'ability', 'to', 'query', 'explore', 'link', 'datasets', 'Has', 'general', 'familiarity', 'with', 'various', 'DB', 'technologies', 'and', 'philosophies', 'such', 'as', 'relational', 'columnar', 'NoSQL', 'technologies', 'Ability', 'to', 'run', 'some', 'analytics', 'aggregations', 'distributions', 'etc', 'Basic', 'coding', 'skills', 'Python', 'R', 'Strong', 'communication', 'stakeholder', 'management', 'and', 'influencing', 'skills', 'Comfortable', 'working', 'in', 'a', 'dynamic', 'fast-paced', 'environment', 'Agile', 'scrum', 'experience', 'Bachelor', "'s", 'degree', 'or', 'equivalent', 'experience', 'required', 'Collaborate', 'with', 'analysts', 'to', 'develop', 'analytics-based', 'answers', 'to', 'questions', 'as', 'part', 'of', 'the', 'investment', 'process', 'Work', 'with', 'multiple', 'sources', 'of', 'data', 'including', 'alternative', 'and', 'proprietary', 'data', 'Design', 'develop', 'and', 'deploy', 'analytical', 'frameworks', 'and', 'scripts', 'to', 'connect', 'and', 'evaluate', 'various', 'data', 'points', 'perform', 'analytics', 'and', 'provide', 'investment', 'related', 'interpretations', 'Analyze', 'data', 'using', 'statistical', 'tools', 'and', 'techniques', 'Analyze', 'trends', 'correlations', 'and', 'patterns', 'in', 'data', 'sets', 'Make', 'recommendations', 'to', 'answer', 'c ...
# ['Understanding', 'business', 'objectives', 'formulating', 'problem', 'Data', 'Science', 'problem', 'Design', 'train', 'deliver', 'Data', 'Science', 'solutions', 'using', 'modalities', 'tabular', 'text', 'image', 'sizes', 'small', 'big', 'data', 'In-depth', 'understanding', 'deep', 'learning', 'building', 'blocks', 'like', 'MLP', 'RNN', 'LSTM', 'CNN', 'Transformers', 'Proficiency', 'least', 'one', 'Deep', 'Learning', 'Framework', 'PyTorch', 'Tensorflow', 'etc', 'Develop', 'maintain', 'robust', 'data', 'processing', 'pipelines', 'reproducible', 'modelling', 'pipelines', 'Explore', 'data', 'communicate', 'insights', 'clearly', 'non-technical', 'well', 'technical', 'audience', 'Analyze', 'experimental', 'results', 'iterate', 'refine', 'models', 'create', 'significant', 'business', 'impact', 'Working', 'knowledge', 'OpenCV', 'Bachelorâ€™s', 'Degree', 'Quantitative', 'discipline', 'preferably', 'Computer', 'Science', '>', '3', 'yearsâ€™', 'experience', 'data', 'science', 'Analytics', 'roles', 'Proven', 'experience', 'Data', 'Scientist', 'similar', 'role', 'Expert', 'ability', 'write', 'robust', 'code', 'Python', 'Familiarity', 'standard', 'machine', 'learning', 'libraries', 'like', 'scikit-learn', 'StatsModels', 'Deep', 'Learning', 'Frameworks', 'like', 'Tensorflow', 'PyTorch', 'etc', 'Completed', 'Projects', 'Computer', 'Vision', 'Natural', 'Language', 'Processing', 'Excellent', 'verbal', 'written', 'communication', 'skills', 'You', 'take', 'complete', 'ownership', 'work', 'self-driven', 'Good', 'Have', 'Familiarity', 'working', 'Azure', 'AWS', 'GCP', 'etc', 'Experience', 'NoSQL', 'databases', 'MongoDB', 'Cassandra', 'Experience', 'containerizing', 'applications', 'using', 'Docker', 'Undertake', 'preprocessing', 'structured', 'unstructured', 'data', 'Create', 'maintain', 'data', 'quality', 'processes', 'Create', 'ETL', 'processes', 'move', 'large', 'amount', 'data', 'Analyze', 'large', 'amounts', 'information', 'discover', 'trends', 'patterns', 'Present', 'information', 'using', 'data', 'visualization', 'techniques', 'Propose', 'solutions', 'strategies', 'business', 'challenges', 'What', 'weâ€™re', 'looking', ':', '5', '8', 'Years', 'experience', 'Data', 'Scientist', 'Data', 'querying', 'data', 'analysis', 'data', 'wrangling', 'well', 'ability', 'query', 'explore', 'link', 'datasets', 'Has', 'general', 'familiarity', 'various', 'DB', 'technologies', 'philosophies', 'relational', 'columnar', 'NoSQL', 'technologies', 'Ability', 'run', 'analytics', 'aggregations', 'distributions', 'etc', 'Basic', 'coding', 'skills', 'Python', 'R', 'Strong', 'communication', 'stakeholder', 'management', 'influencing', 'skills', 'Comfortable', 'working', 'dynamic', 'fast-paced', 'environment', 'Agile', 'scrum', 'experience', 'Bachelor', "'s", 'degree', 'equivalent', 'experience', 'required', 'Collaborate', 'analysts', 'develop', 'analytics-based', 'answers', 'questions', 'part', 'investment', 'process', 'Work', 'multiple', 'sources', 'data', 'including', 'alternative', 'proprietary', 'data', 'Design', 'develop', 'deploy', 'analytical', 'frameworks', 'scripts', 'connect', 'evaluate', 'various', 'data', 'points', 'perform', 'analytics', 'provide', 'investment', 'related', 'interpretations', 'Analyze', 'data', 'using', 'statistical', 'tools', 'techniques', 'Analyze', 'trends', 'correlations', 'patterns', 'data', 'sets', 'Make', 'recommendations', 'answer', 'complex', 'business', 'queries', 'implement', 'solutions', 'Bachelors', 'Mastersâ€™', 'degree', 'Statistics', 'Computer', 'Science', 'related', 'field', '3-8', 'yearsâ€™', 'experience', 'data', 'science', 'related', 'fields', 'Strong', 'analytical', 'programming', 'skills', 'Python', 'SQL', 'Excel', 'must', 'VBA', 'plus', 'good', 'understanding', 'packages', 'Pandas', 'Numpy', 'Scikit', 'learn', 'Experience', 'text', 'mining', 'NLP', 'Good', 'understanding', 'classification', 'clustering', 'tools', 'techniques', 'PCA', 'Random', 'Forest', 'SVM', 'K-means', 'etc', 'Experience', 'working', 'time', 'serie ...

# %%
sentence = ""
for x in filtered_sentence:
    stringb = stringb + str(x) + " "

# %%
sentence
# Out:
# "Understanding  objectives formulating problem   problem Design train deliver   solutions  modalities tabular text image sizes small big  In-depth understanding deep  building blocks like MLP RNN LSTM CNN Transformers Proficiency least one Deep Learning Framework PyTorch Tensorflow  Develop maintain robust  processing pipelines reproducible ling pipelines Explore  communicate insights clearly non-technical well technical audience Analyze experimental results iterate refine s create significant  impact Working knowledge OpenCV Bachelorâ€™s Degree Quantitative discipline preferably Computer  > 3 â€™    Analytics roles Proven   Scientist similar role Expert ability write robust code Python Familiarity standard machine  libraries like scikit-learn StatsModels Deep Learning Frameworks like Tensorflow PyTorch  Completed Projects Computer Vision Natural Language Processing Excellent verbal written communication  You take complete ownership work self-driven Good Have Familiarity  Azure AWS GCP   NoSQL bases MongoDB Cassandra  containerizing applications  Docker Undertake preprocessing structured unstructured  Create maintain  quality processes Create ETL processes move large amount  Analyze large amounts information discover trends patterns Present information   visualization  Propose solutions strategies  challenges What weâ€™re looking : 5 8 Years   Scientist  querying  analysis  wrangling well ability query explore link sets Has general familiarity various DB technologies philosophies relational columnar NoSQL technologies Ability run analytics aggregations distributions  Basic coding  Python R Strong communication stakeholder management influencing  Comfortable  dynamic fast-paced environment Agile scrum  Bachelor 's degree equivalent  required Collaborate analysts develop analytics-based answers questions part investment process Work multiple sources  including alternative proprietary  Design develop deploy analytical frameworks scripts connect evaluate various  points perform analytics provide investment related interpretations Analyze   statistical   Analyze trends correlations patterns  sets Make recommendations answer complex  queries implement solutions Bachelors Mastersâ€™ degree Statistics Computer  related field 3-8 â€™    related fields Strong analytical programming  Python SQL Excel must VBA plus good understanding packages Pandas Numpy Scikit learn  text mining NLP Good understanding classification clustering   PCA Random Forest SVM K-means    time series  Have  projects leverage programming perform ing visualization web scraping tasks Understanding interest finance markets plus Ability explain technical concepts non-technical audiences Ability work imperfect information Strong oral written communication  Self-starter strong  orientation We seeking hands  Scientist join growing team building  processing pipelines machine  s  Python Azure DevOps Azure Machine Learning Azure Functions Azure  Lake Azure  Factory Azure bricks Spark PySpark Scikit-learn TensorFlow Keras PyTorch  Most recent work  MUST include work Python Azure Machine Learning Azure Functions Azure  Lake Azure  Factory Azure bricks Spark Azure DevOps PySpark Scikit-learn TensorFlow Keras PyTorch  Build predictive ing capabilities Personal Insurance pricing analytics interacting  partners b : Develop pricing s  SAS R Python machine   independently c : Build cross sell s propensity s market mix s - Work various analytical problems improve efficiency throughout lifecycle individual insurance products viz auto property Minimum 6   predictive ing b : Minimum 3      machine   c :    intelligence  eg Tableau  frameworks eg Hadoop Analytical mind  acumen Good communication interpersonal  b : Strong writing  stakeholder management c : Excellent problem-solving  mitigate technical issues : Proactive take ownership Maintain intimate understanding company department strategy Translate analysis requirements  requirements Identify understand  sources relevant  problem De ...

# %%
sentence = sentence.replace(' s ','')
sentence
# Out:
# "Understanding  objectives formulating problem   problem Design train deliver   solutions  modalities tabular text image sizes small big  In-depth understanding deep  building blocks like MLP RNN LSTM CNN Transformers Proficiency least one Deep Learning Framework PyTorch Tensorflow  Develop maintain robust  processing pipelines reproducible ling pipelines Explore  communicate insights clearly non-technical well technical audience Analyze experimental results iterate refinecreate significant  impact Working knowledge OpenCV Bachelorâ€™s Degree Quantitative discipline preferably Computer  > 3 â€™    Analytics roles Proven   Scientist similar role Expert ability write robust code Python Familiarity standard machine  libraries like scikit-learn StatsModels Deep Learning Frameworks like Tensorflow PyTorch  Completed Projects Computer Vision Natural Language Processing Excellent verbal written communication  You take complete ownership work self-driven Good Have Familiarity  Azure AWS GCP   NoSQL bases MongoDB Cassandra  containerizing applications  Docker Undertake preprocessing structured unstructured  Create maintain  quality processes Create ETL processes move large amount  Analyze large amounts information discover trends patterns Present information   visualization  Propose solutions strategies  challenges What weâ€™re looking : 5 8 Years   Scientist  querying  analysis  wrangling well ability query explore link sets Has general familiarity various DB technologies philosophies relational columnar NoSQL technologies Ability run analytics aggregations distributions  Basic coding  Python R Strong communication stakeholder management influencing  Comfortable  dynamic fast-paced environment Agile scrum  Bachelor 's degree equivalent  required Collaborate analysts develop analytics-based answers questions part investment process Work multiple sources  including alternative proprietary  Design develop deploy analytical frameworks scripts connect evaluate various  points perform analytics provide investment related interpretations Analyze   statistical   Analyze trends correlations patterns  sets Make recommendations answer complex  queries implement solutions Bachelors Mastersâ€™ degree Statistics Computer  related field 3-8 â€™    related fields Strong analytical programming  Python SQL Excel must VBA plus good understanding packages Pandas Numpy Scikit learn  text mining NLP Good understanding classification clustering   PCA Random Forest SVM K-means    time series  Have  projects leverage programming perform ing visualization web scraping tasks Understanding interest finance markets plus Ability explain technical concepts non-technical audiences Ability work imperfect information Strong oral written communication  Self-starter strong  orientation We seeking hands  Scientist join growing team building  processing pipelines machine  Python Azure DevOps Azure Machine Learning Azure Functions Azure  Lake Azure  Factory Azure bricks Spark PySpark Scikit-learn TensorFlow Keras PyTorch  Most recent work  MUST include work Python Azure Machine Learning Azure Functions Azure  Lake Azure  Factory Azure bricks Spark Azure DevOps PySpark Scikit-learn TensorFlow Keras PyTorch  Build predictive ing capabilities Personal Insurance pricing analytics interacting  partners b : Develop pricing SAS R Python machine   independently c : Build cross sellpropensitymarket mix- Work various analytical problems improve efficiency throughout lifecycle individual insurance products viz auto property Minimum 6   predictive ing b : Minimum 3      machine   c :    intelligence  eg Tableau  frameworks eg Hadoop Analytical mind  acumen Good communication interpersonal  b : Strong writing  stakeholder management c : Excellent problem-solving  mitigate technical issues : Proactive take ownership Maintain intimate understanding company department strategy Translate analysis requirements  requirements Identify understand  sources relevant  problem Develop conceptualca ...

# %%
wordcloud = WordCloud(width = 3000, 
                      height = 2000, random_state=1, 
                      background_color='salmon', 
                      colormap='Pastel1', 
                      collocations=False, 
                      stopwords = STOPWORDS).generate(sentence)

# %%
# Set figure size
plt.figure(figsize=(40, 30))
# Display image
plt.imshow(wordcloud) 
# No axis details
plt.axis("off")
# Out:
# (-0.5, 2999.5, 1999.5, -0.5)
