# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('fake_reg.csv')

# %%
df
# Out:
#           price     feature1     feature2
# 0    461.527929   999.787558   999.766096
# 1    548.130011   998.861615  1001.042403
# 2    410.297162  1000.070267   998.844015
# 3    540.382220   999.952251  1000.440940
# 4    546.024553  1000.446011  1000.338531
# ..          ...          ...          ...
# 995  476.526078  1000.018988   999.672732
# 996  457.313186   998.855379  1000.020026
# 997  456.720992  1001.451646   998.847606
# 998  403.315576  1000.771023   998.562851
# 999  599.367093   999.232244  1001.451407
#
# [1000 rows x 3 columns]

# %%
sns.pairplot(df)

# %%
from sklearn.model_selection import train_test_split

# %%
X = df[['feature1','feature2']].values
y = df['price']

# %%
y
# Out:
# 0      461.527929
# 1      548.130011
# 2      410.297162
# 3      540.382220
# 4      546.024553
#           ...
# 995    476.526078
# 996    457.313186
# 997    456.720992
# 998    403.315576
# 999    599.367093
# Name: price, Length: 1000, dtype: float64

# %%
X
# Out:
# array([[ 999.78755752,  999.7660962 ],
#        [ 998.86161491, 1001.04240315],
#        [1000.07026691,  998.84401463],
#        ...,
#        [1001.45164617,  998.84760554],
#        [1000.77102275,  998.56285086],
#        [ 999.2322436 , 1001.45140713]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.33, random_state=0)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train = scaler.transform(X_train)

# %%
X_train.max()
# Out:
# 1.0

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
help(Sequential)
# Out:
# Help on class Sequential in module tensorflow.python.keras.engine.sequential:
#
# class Sequential(tensorflow.python.keras.engine.functional.Functional)
#  |  Sequential(*args, **kwargs)
#  |
#  |  `Sequential` groups a linear stack of layers into a `tf.keras.Model`.
#  |
#  |  `Sequential` provides training and inference features on this model.
#  |
#  |  Examples:
#  |
#  |  >>> # Optionally, the first layer can receive an `input_shape` argument:
#  |  >>> model = tf.keras.Sequential()
#  |  >>> model.add(tf.keras.layers.Dense(8, input_shape=(16,)))
#  |  >>> # Afterwards, we do automatic shape inference:
#  |  >>> model.add(tf.keras.layers.Dense(4))
#  |
#  |  >>> # This is identical to the following:
#  |  >>> model = tf.keras.Sequential()
#  |  >>> model.add(tf.keras.Input(shape=(16,)))
#  |  >>> model.add(tf.keras.layers.Dense(8))
#  |
#  |  >>> # Note that you can also omit the `input_shape` argument.
# ...

# %%
model = Sequential()

# %%
model.add(Dense(4, activation='relu'))
model.add(Dense(4, activation='relu'))
model.add(Dense(4, activation='relu'))
model.add(Dense(1))

model.compile(optimizer='rmsprop',loss='mse')

# %%
model.fit(x=X_train,y=y_train,epochs=300)
# Out:
# Epoch 1/250
# 21/21 [==============================] - 1s 1ms/step - loss: 253785.8331
# Epoch 2/250
# 21/21 [==============================] - 0s 1ms/step - loss: 257790.8913
# Epoch 3/250
# 21/21 [==============================] - 0s 1ms/step - loss: 258879.4496
# Epoch 4/250
# 21/21 [==============================] - 0s 1ms/step - loss: 256422.4794
# Epoch 5/250
# 21/21 [==============================] - 0s 1ms/step - loss: 256622.8615
# Epoch 6/250
# 21/21 [==============================] - 0s 1ms/step - loss: 259212.4112
# Epoch 7/250
# 21/21 [==============================] - 0s 2ms/step - loss: 253264.3594
# Epoch 8/250
# 21/21 [==============================] - 0s 2ms/step - loss: 259206.5369
# Epoch 9/250
# 21/21 [==============================] - 0s 2ms/step - loss: 257170.2259
# Epoch 10/250
# 21/21 [==============================] - 0s 2ms/step - loss: 256892.9446
# Epoch 11/250
# 21/21 [==============================] - 0s 1ms/step - loss: 254139.3665
# Epoch 12/250
# ...

# %%
lossdf = pd.DataFrame(model.history.history)

# %%
lossdf.plot()
# Out:
# <AxesSubplot:>

# %%
scaler = MinMaxScaler()

# %%
X_test = scaler.fit_transform(X_test)

# %%
model.evaluate(X_test,y_test,verbose=0)
# Out:
# 256.40966796875

# %%
model.evaluate(X_train,y_train,verbose=0)
# Out:
# 24.30653953552246

# %%
test_prediction = model.predict(X_test)
test_prediction
# Out:
# array([[527.0114 ],
#        [570.39294],
#        [514.2203 ],
#        [530.671  ],
#        [556.62427],
#        [565.05255],
#        [586.3089 ],
#        [527.44434],
#        [546.9378 ],
#        [618.63495],
#        [518.1572 ],
#        [649.9002 ],
#        [434.121  ],
#        [356.70572],
#        [417.13626],
#        [581.0219 ],
#        [356.07962],
#        [602.7325 ],
#        [493.2717 ],
#        [513.8646 ],
#        [323.973  ],
#        [611.7582 ],
#        [565.25616],
#        [475.98596],
#        [690.2397 ],
#        [666.2462 ],
#        [672.4653 ],
#        [473.57492],
#        [432.4954 ],
#        [570.42957],
#        [660.7408 ],
#        [588.1048 ],
#        [537.3977 ],
#        [368.5632 ],
#        [669.6565 ],
#        [463.1279 ],
#        [599.61554],
#        [332.24512],
#        [375.7926 ],
#        [379.96164],
#        [603.3502 ],
#        [472.4641 ],
#        [452.52063],
#        [427.12686],
#        [602.85986],
# ...

# %%
test_prediction = pd.Series(test_prediction.reshape(330,))

# %%
y_truevalues = pd.Series(y_test.values.reshape(330 ,))

# %%
pred_df = pd.concat([test_prediction,y_truevalues],axis=1)

# %%
pred_df.columns = ['True y', 'Model preditions']

# %%
sns.scatterplot(x='True y',y='Model preditions',data=pred_df)
# Out:
# <AxesSubplot:xlabel='True y', ylabel='Model preditions'>

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
pred_df['Model preditions']
# Out:
# 0      518.356144
# 1      551.650100
# 2      511.366708
# 3      518.127883
# 4      547.624043
#           ...
# 325    547.731982
# 326    514.479066
# 327    585.156692
# 328    637.778969
# 329    484.436384
# Name: Model preditions, Length: 330, dtype: float64

# %%
mean_absolute_error(pred_df['True y'],pred_df['Model preditions'])
# Out:
# 13.874843068846745

# %%
mean_squared_error(pred_df['True y'],pred_df['Model preditions'])**0.5
# Out:
# 16.012796557758396

# %%
df.describe()
# Out:
#              price     feature1     feature2
# count  1000.000000  1000.000000  1000.000000
# mean    498.673029  1000.014171   999.979847
# std      93.785431     0.974018     0.948330
# min     223.346793   997.058347   996.995651
# 25%     433.025732   999.332068   999.316106
# 50%     502.382117  1000.009915  1000.002243
# 75%     564.921588  1000.637580  1000.645380
# max     774.407854  1003.207934  1002.666308
